# %% [markdown]
# <a href="https://colab.research.google.com/github/jonkrohn/ML-foundations/blob/master/notebooks/1-intro-to-linear-algebra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intro to Linear Algebra

# %% [markdown]
# This topic, *Intro to Linear Algebra*, is the first in the *Machine Learning Basics*.
#
# Linear algebra underpins most machine learning, especially deep learning at the forefront of AI. Through clear theory and interactive examples, you’ll learn how it helps solve high-dimensional problems, enabling machines to recognize patterns and make predictions.

# %% [markdown]
# During this topic, you'll:
#
# * Learn the fundamentals of linear algebra for solving high-dimensional problems.
# * Build geometric intuition behind machine learning and deep learning algorithms.
# * Gain the foundation needed to better understand ML papers and related fields like calculus, statistics, and optimization.

# %% [markdown]
# # * *1: Data Structures for Algebra*
#
# * What Linear Algebra Is
# * Tensors
# * Scalars
# * Vectors and Vector Transposition
# * Norms and Unit Vectors
# * Basis, Orthogonal, and Orthonormal Vectors
# * Arrays in NumPy
# * Matrices
# * Tensors in TensorFlow and PyTorch

# %% [markdown]
# ### What Linear Algebra Is

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.linspace(0, 40, 1000) # start, finish, n points

# %% [markdown]
# Distance travelled by robber: $d = 2.5t$

# %%
d_r = 2.5 * t

# %% [markdown]
# Distance travelled by sheriff: $d = 3(t-5)$

# %%
d_s = 3 * (t-5)

# %%
fig, ax = plt.subplots()
plt.title('A Bank Thief Reached')
plt.xlabel('time (in minutes)')
plt.ylabel('distance (in km)')
ax.set_xlim([0, 40])
ax.set_ylim([0, 100])
ax.plot(t, d_r, c='green')
ax.plot(t, d_s, c='brown')
plt.axvline(x=30, color='purple', linestyle='--')
_ = plt.axhline(y=75, color='purple', linestyle='--')

# %% [markdown]
# **Return to slides here.**

# %% [markdown]
# ### Scalars (Rank 0 Tensors) in Base Python

# %%
x = 25
x
# Out:
# 25

# %%
type(x) # if we'd like more specificity (e.g., int16, uint8), we need NumPy or another numeric library
# Out:
# int

# %%
y = 3

# %%
py_sum = x + y
py_sum
# Out:
# 28

# %%
type(py_sum)
# Out:
# int

# %%
x_float = 25.0
float_sum = x_float + y
float_sum
# Out:
# 28.0

# %%
type(float_sum)
# Out:
# float

# %% [markdown]
# ### Scalars in PyTorch
#
# * PyTorch and TensorFlow are the two most widely used automatic differentiation libraries in Python, the leading language for machine learning.
# * PyTorch tensors are designed to be pythonic, meaning they behave similarly to NumPy arrays. A key advantage of PyTorch tensors over NumPy arrays is their native support for GPU acceleration, enabling efficient computation on large-scale data.

# %%
import torch

# %%
x_pt = torch.tensor(25) # type specification optional, e.g.: dtype=torch.float16
x_pt
# Out:
# tensor(25)

# %%
x_pt.shape
# Out:
# torch.Size([])

# %% [markdown]
# ### Scalars in TensorFlow (version 2.0 or later)
#
# Tensors created with a wrapper, all of which [you can read about here](https://www.tensorflow.org/guide/tensor):
#
# * `tf.Variable`
# * `tf.constant`
# * `tf.placeholder`
# * `tf.SparseTensor`
#
# Most widely-used is `tf.Variable`, which we'll use here.
#
# As with TF tensors, in PyTorch we can similarly perform operations, and we can easily convert to and from NumPy arrays.
#
# Also, a full list of tensor data types is available [here](https://www.tensorflow.org/api_docs/python/tf/dtypes/DType).

# %%
import tensorflow as tf

# %%
x_tf = tf.Variable(25, dtype=tf.int16) # dtype is optional
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int16, numpy=25>

# %%
x_tf.shape
# Out:
# TensorShape([])

# %%
y_tf = tf.Variable(3, dtype=tf.int16)

# %%
x_tf + y_tf
# Out:
# <tf.Tensor: shape=(), dtype=int16, numpy=28>

# %%
tf_sum = tf.add(x_tf, y_tf)
tf_sum
# Out:
# <tf.Tensor: shape=(), dtype=int16, numpy=28>

# %%
tf_sum.numpy() # note that NumPy operations automatically convert tensors to NumPy arrays, and vice versa
# Out:
# np.int16(28)

# %%
type(tf_sum.numpy())
# Out:
# numpy.int16

# %%
tf_float = tf.Variable(25., dtype=tf.float16)
tf_float
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float16, numpy=25.0>

# %% [markdown]
# **Return to slides here.**

# %% [markdown]
# ### Vectors (Rank 1 Tensors) in NumPy

# %%
x = np.array([25, 2, 5]) # type argument is optional, e.g.: dtype=np.float16
x
# Out:
# array([25,  2,  5])

# %%
len(x)
# Out:
# 3

# %%
x.shape
# Out:
# (3,)

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x[0] # zero-indexed
# Out:
# np.int64(25)

# %%
type(x[0])
# Out:
# numpy.int64

# %% [markdown]
# ### Vector Transposition

# %%
# Transposing a regular 1-D array has no effect...
x_t = x.T
x_t
# Out:
# array([25,  2,  5])

# %%
x_t.shape
# Out:
# (3,)

# %%
# ...but it does we use nested "matrix-style" brackets:
y = np.array([[25, 2, 5]])
y
# Out:
# array([[25,  2,  5]])

# %%
y.shape
# Out:
# (1, 3)

# %%
# ...but can transpose a matrix with a dimension of length 1, which is mathematically equivalent:
y_t = y.T
y_t
# Out:
# array([[25],
#        [ 2],
#        [ 5]])

# %%
y_t.shape # this is a column vector as it has 3 rows and 1 column
# Out:
# (3, 1)

# %%
# Column vector can be transposed back to original row vector:
y_t.T
# Out:
# array([[25,  2,  5]])

# %%
y_t.T.shape
# Out:
# (1, 3)

# %% [markdown]
# ### Zero Vectors
#
# Have no effect if added to another vector

# %%
z = np.zeros(3)
z
# Out:
# array([0., 0., 0.])

# %% [markdown]
# ### Vectors in PyTorch and TensorFlow

# %%
x_pt = torch.tensor([25, 2, 5])
x_pt
# Out:
# tensor([25,  2,  5])

# %%
x_tf = tf.Variable([25, 2, 5])
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([25,  2,  5], dtype=int32)>

# %% [markdown]
# **Return to slides here.**

# %% [markdown]
# ### $L^2$ Norm

# %%
x
# Out:
# array([25,  2,  5])

# %%
(25**2 + 2**2 + 5**2)**(1/2)
# Out:
# 25.573423705088842

# %%
np.linalg.norm(x)
# Out:
# np.float64(25.573423705088842)

# %% [markdown]
# So, if units in this 3-dimensional vector space are meters, then the vector $x$ has a length of 25.6m

# %% [markdown]
# **Return to slides here.**

# %% [markdown]
# ### $L^1$ Norm

# %%
x
# Out:
# array([25,  2,  5])

# %%
np.abs(25) + np.abs(2) + np.abs(5)
# Out:
# np.int64(32)

# %% [markdown]
# **Return to slides here.**

# %% [markdown]
# ### Squared $L^2$ Norm

# %%
x
# Out:
# array([25,  2,  5])

# %%
(25**2 + 2**2 + 5**2)
# Out:
# 654

# %%
# we'll cover tensor multiplication more soon but to prove point quickly:
np.dot(x, x)
# Out:
# np.int64(654)

# %% [markdown]
# **Return to slides here.**

# %% [markdown]
# ### Max Norm

# %%
x
# Out:
# array([25,  2,  5])

# %%
np.max([np.abs(25), np.abs(2), np.abs(5)])
# Out:
# np.int64(25)

# %% [markdown]
# **Return to slides here.**

# %% [markdown]
# ### Orthogonal Vectors

# %%
i = np.array([1, 0])
i
# Out:
# array([1, 0])

# %%
j = np.array([0, 1])
j
# Out:
# array([0, 1])

# %%
np.dot(i, j) # detail on the dot operation coming up...
# Out:
# np.int64(0)

# %% [markdown]
# **Return to slides here.**

# %% [markdown]
# ### Matrices (Rank 2 Tensors) in NumPy

# %%
# Use array() with nested brackets:
X = np.array([[25, 2], [5, 26], [3, 7]])
X
# Out:
# array([[25,  2],
#        [ 5, 26],
#        [ 3,  7]])

# %%
X.shape
# Out:
# (3, 2)

# %%
X.size
# Out:
# 6

# %%
# Select left column of matrix X (zero-indexed)
X[:,0]
# Out:
# array([25,  5,  3])

# %%
# Select middle row of matrix X:
X[1,:]
# Out:
# array([ 5, 26])

# %%
# Another slicing-by-index example:
X[0:2, 0:2]
# Out:
# array([[25,  2],
#        [ 5, 26]])

# %% [markdown]
# ### Matrices in PyTorch

# %%
X_pt = torch.tensor([[25, 2], [5, 26], [3, 7]])
X_pt
# Out:
# tensor([[25,  2],
#         [ 5, 26],
#         [ 3,  7]])

# %%
X_pt.shape # pythonic relative to TensorFlow
# Out:
# torch.Size([3, 2])

# %%
X_pt[1,:] # N.B.: Python is zero-indexed; written algebra is one-indexed
# Out:
# tensor([ 5, 26])

# %% [markdown]
# ### Matrices in TensorFlow

# %%
X_tf = tf.Variable([[25, 2], [5, 26], [3, 7]])
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3, 2) dtype=int32, numpy=
# array([[25,  2],
#        [ 5, 26],
#        [ 3,  7]], dtype=int32)>

# %%
tf.rank(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=2>

# %%
tf.shape(X_tf)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([3, 2], dtype=int32)>

# %%
X_tf[1,:]
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([ 5, 26], dtype=int32)>

# %% [markdown]
# **Return to slides here.**

# %% [markdown]
# ### Higher-Rank Tensors
#
# As an example, rank 4 tensors are common for images, where each dimension corresponds to:
#
# 1. Number of images in training batch, e.g., 32
# 2. Image height in pixels, e.g., 28 for [MNIST digits](http://yann.lecun.com/exdb/mnist/)
# 3. Image width in pixels, e.g., 28
# 4. Number of color channels, e.g., 3 for full-color images (RGB)

# %%
images_pt = torch.zeros([32, 28, 28, 3])

# %%
# images_pt

# %%
images_tf = tf.zeros([32, 28, 28, 3])

# %%
# images_tf

# %% [markdown]
# **Return to slides here.**
